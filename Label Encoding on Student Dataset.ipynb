# %%
df=pd.read_csv("student.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
dct={"bachelor's degree":5, 'some college':3, "master's degree":6,
       "associate's degree":4, 'high school':2, 'some high school':1}

# %%
dct
# Out:
# {"bachelor's degree": 5,
#  'some college': 3,
#  "master's degree": 6,
#  "associate's degree": 4,
#  'high school': 2,
#  'some high school': 1}

# %%
df['parental level of education']=df['parental level of education'].map(dct)

# %%
df.head()
# Out:
#    gender race/ethnicity  parental level of education         lunch  \
# 0  female        group B                            5      standard
# 1  female        group C                            3      standard
# 2  female        group B                            6      standard
# 3    male        group A                            4  free/reduced
# 4    male        group C                            3      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
pd.get_dummies(data=df,drop_first=True)
# Out:
#      parental level of education  math score  reading score  writing score  \
# 0                              5          72             72             74
# 1                              3          69             90             88
# 2                              6          90             95             93
# 3                              4          47             57             44
# 4                              3          76             78             75
# ..                           ...         ...            ...            ...
# 995                            6          88             99             95
# 996                            2          62             55             55
# 997                            2          59             71             65
# 998                            3          68             78             77
# 999                            3          77             86             86
#
#      gender_male  race/ethnicity_group B  race/ethnicity_group C  \
# ...
